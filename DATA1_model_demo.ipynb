# %% [markdown]
# # Pyomo model demo:
# # Multi-period Diafiltration Experiment
# # DATA1
#
# Xinhong Liu xliu27@nd.edu

# %% [markdown]
# ### Import library

# %%
from utility import *

# %% [markdown]
# ### NF90-DATA model reproduce
# Diafiltration w/ conductivity measurements and considering concentration polarization

# %%
data_stru = loadmat('data_library/data_stru-dataset511.12.mat')['data_stru']
sim_stru=[]
plot_sim_comparison(data_stru,sim_stru,plot_pred=False,lg=True,LOUD=False)

# %%
mode = 'DATA'
fit_stru, sim_stru, sim_inter = solve_model(data_stru, mode, sim_opt=False, B_form='single')
plot_sim_comparison(data_stru,sim_stru,stirc_mass=False,plot_pred=True,lg=False,LOUD=False)
# Out:
# Ipopt 3.13.2: linear_solver=ma97
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver ma97.
#
# Number of nonzeros in equality constraint Jacobian...:   120347
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    30168
#
# Total number of variables............................:    36123
#                      variables with only lower bounds:    15050
#                 variables with lower and upper bounds:        3
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:    36120
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.8344456e+08 3.16e+01 9.92e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  6.5706614e+08 2.91e+01 7.41e+03  -1.0 2.11e+01    -  5.51e-03 8.09e-02f  1
#    2  5.7314983e+08 1.79e+01 1.91e+04  -1.0 1.49e+01    -  9.97e-02 3.83e-01f  1
#    3  5.7267231e+08 1.79e+01 1.90e+04  -1.0 9.73e+00    -  6.42e-02 3.52e-03h  1
#    4  5.1552660e+08 5.75e+00 1.43e+04  -1.0 1.47e+01    -  6.23e-02 6.78e-01f  1
#    5  5.1499489e+08 5.62e+00 1.40e+04  -1.0 3.05e+00    -  5.77e-01 2.24e-02h  1
#    6  5.1458211e+08 5.60e+00 1.39e+04  -1.0 8.32e+00    -  6.56e-04 3.87e-03f  1
#    7  5.0976749e+08 4.51e+00 1.12e+04  -1.0 5.03e+00    -  7.37e-01 1.94e-01f  1
#    8  5.0610009e+08 4.43e+00 1.10e+04  -1.0 1.40e+01    -  2.59e-01 1.95e-02f  1
#    9  3.2074001e+08 3.08e+00 1.13e+05  -1.0 1.56e+01    -  8.20e-02 9.91e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.7307732e+08 6.02e-01 2.87e+06  -1.0 1.19e+01    -  1.06e-02 5.27e-01f  1
#   11  2.7252986e+08 5.95e-01 2.83e+06  -1.0 6.23e+00    -  2.00e-01 1.31e-02f  1
#   12  2.6498953e+08 6.13e-01 1.64e+06  -1.0 3.17e+00    -  4.44e-02 1.00e+00f  1
#   13  2.3030827e+08 1.05e+00 6.84e+06  -1.0 1.67e+01    -  6.01e-02 2.59e-01f  1
#   14  1.1947593e+08 1.12e+01 7.58e+07  -1.0 1.76e+01    -  3.08e-01 9.90e-01f  1
#   15  4.9462334e+07 2.16e+01 3.00e+06  -1.0 2.40e+01    -  5.09e-01 1.00e+00f  1
#   16  4.8720771e+07 1.77e+01 9.75e+04  -1.0 3.59e+01    -  7.23e-03 1.00e+00f  1
#   17  4.6645025e+07 8.48e+00 2.66e+04  -1.0 1.15e+01    -  7.27e-01 3.93e-01f  1
#   18  4.7062260e+07 8.30e+00 2.15e+04  -1.0 1.16e+01    -  1.00e+00 2.10e-02h  1
#   19  7.7181661e+07 2.86e+00 1.56e+03  -1.0 1.67e+01    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  1.9478135e+07 2.33e+01 1.60e+04  -1.7 4.55e+01    -  1.00e+00 1.00e+00f  1
#   21  1.0234299e+07 2.10e+00 1.72e+03  -1.7 4.99e+00    -  1.00e+00 1.00e+00h  1
#   22  9.4013380e+06 4.24e-02 2.73e+01  -1.7 7.94e-01    -  1.00e+00 1.00e+00h  1
#   23  1.7810290e+06 6.44e+00 4.52e+03  -3.8 1.58e+01    -  9.97e-01 1.00e+00f  1
#   24  1.0638206e+06 9.03e-01 6.08e+02  -3.8 3.24e+00    -  6.96e-01 1.00e+00h  1
#   25  1.0134789e+06 1.31e-02 2.05e+01  -3.8 7.48e-01    -  1.00e+00 1.00e+00h  1
#   26  1.0128518e+06 1.95e-04 1.60e-01  -3.8 6.70e-02    -  1.00e+00 1.00e+00h  1
#   27  1.0128473e+06 2.06e-09 1.12e-06  -3.8 1.51e-04    -  1.00e+00 1.00e+00h  1
#   28  1.0114688e+06 1.97e-03 8.86e+00  -5.7 2.17e-01    -  9.40e-01 1.00e+00f  1
#   29  1.0114374e+06 2.20e-07 1.87e-04  -5.7 1.98e-03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  1.0114374e+06 9.07e-12 1.51e-10  -5.7 1.49e-06    -  1.00e+00 1.00e+00h  1
#   31  1.0114372e+06 3.15e-07 2.78e-04  -8.6 2.74e-03    -  1.00e+00 1.00e+00h  1
#   32  1.0114372e+06 8.87e-12 4.79e-12  -8.6 3.18e-07    -  1.00e+00 1.00e+00h  1
#   33  1.0114372e+06 8.49e-12 5.01e-10 -10.5 3.68e-06    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 33
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.6770320663518921e+00    1.0114371828709466e+06
# Dual infeasibility......:   5.0065050933092992e-10    1.3771338721638445e-04
# Constraint violation....:   2.8282693520509641e-12    8.4856566218149965e-12
# Complementarity.........:   3.3050145215656640e-11    9.0910672431433654e-06
# Overall NLP error.......:   5.0065050933092992e-10    1.3771338721638445e-04
#
#
# Number of objective function evaluations             = 34
# Number of objective gradient evaluations             = 34
# Number of equality constraint evaluations            = 34
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 34
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 33
# Total CPU secs in IPOPT (w/o function evaluations)   =      3.549
# Total CPU secs in NLP function evaluations           =      0.571
#
# EXIT: Optimal Solution Found.
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 36120
#   Number of variables: 36123
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: Ipopt 3.13.2\x3a Optimal Solution Found
#   Termination condition: optimal
#   Id: 0
#   Error rc: 0
#   Time: 4.792173147201538
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# Lp =  3.282734034967208  L / m / m / hr / bar
# B =  0.28670565586099434  micrometers / s
# sigma =  0.9738729175069187  dimensionless
# cD =  78.84381925  mM
# Obj =  1011437.1828709439
# Obj(m) =  16.77785747658106
# Obj(cv) =  23.53344680450589
# Obj(cr) =  60.83241400600744
# count =  2996
# count(m) =  2968
# count(cv) =  10
# count(cr) =  18
# likelihood1 =  8475.468545541984
# likelihood2 =  -19140.081984081015
# WARNING: DEPRECATED: Using __getitem__ to return a set value from its
# (ordered) position is deprecated.  Please use at()  (deprecated in 6.1, will
# be removed in (or after) 7.0) (called from E:\了不得的PhD\Research\Git\dynamic-
# diafiltration-pyomo\utility.py:313)

# %% [markdown]
# ### FIM calculation

# %%
#doe_stru = calc_FIM(data_stru, mode, theta=fit_stru['parameters'], step=1e-8, formula='Backward', B_form='single')
